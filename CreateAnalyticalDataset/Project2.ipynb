# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('p2-2010-pawdacity-monthly-sales-p2-2010-pawdacity-monthly-sales.csv',header=0)
df.head()
# Out:
#         NAME                       ADDRESS      CITY STATE    ZIP  January  \
# 0  Pawdacity               509 Fort St # A   Buffalo    WY  82834    16200
# 1  Pawdacity  601 SE Wyoming Blvd Unit 252    Casper    WY  82609    29160
# 2  Pawdacity             3769 E Lincolnway  Cheyenne    WY  82001    79920
# 3  Pawdacity             2625 Big Horn Ave      Cody    WY  82414    19440
# 4  Pawdacity                  123 S 2nd St   Douglas    WY  82633    16200
#
#    February  March  April    May   June   July  August  September  October  \
# 0     13392  14688  17064  18360  14040  12960   19224      15984    13392
# 1     21600  27000  27648  29160  27216  25488   25704      22896    25272
# 2     70632  79056  77544  73656  77976  73872   77544      78516    74520
# 3     15984  19008  18144  16632  17496  18792   20304      19224    18144
# 4     13392  14688  17064  18360  14040  12960   19224      15984    29808
#
#    November  December
# 0     13176     16848
# ...

# %%
df.value_counts('NAME')
# Out:
# NAME
# Pawdacity    11
# dtype: int64

# %%
df1 = pd.read_csv('p2-partially-parsed-wy-web-scrape.csv',header=0)
df1.head()
# Out:
#           City|County   2014 Estimate     2010 Census     2000 Census
# 0       Afton|Lincoln  <td>1,968</td>  <td>1,911</td>  <td>1,818</td>
# 1       Albin|Laramie    <td>185</td>    <td>181</td>    <td>120</td>
# 2      Alpine|Lincoln    <td>845</td>    <td>828</td>    <td>550</td>
# 3        Baggs|Carbon    <td>439</td>    <td>440</td>    <td>348</td>
# 4  Bairoil|Sweetwater    <td>107</td>    <td>106</td>     <td>97</td>

# %%
df2 = pd.read_csv('p2-wy-453910-naics-data.csv',header=0)
df2.head()
# Out:
#                   BUSINESS NAME PHYSICAL CITY NAME  SALES VOLUME  \
# 0      Mile High Mobile Pet LLC           Cheyenne        300000
# 1                 Pets City Inc           Cheyenne        640000
# 2  Petco Animal Sups Stores Inc           Cheyenne             0
# 3                    Pet-A-Care           Cheyenne         81000
# 4          Muddy Paws Pet Salon            Laramie         76000
#
#              CASS_LastLine
# 0  Cheyenne, WY 82007-3528
# 1  Cheyenne, WY 82009-4851
# 2  Cheyenne, WY 82009-4945
# 3  Cheyenne, WY 82009-1009
# 4   Laramie, WY 82070-8979

# %%
df3 = pd.read_csv('p2-wy-demographic-data.csv',header=0)
df3.head()
# Out:
#          City    County    Land Area  Households with Under 18  \
# 0     Laramie    Albany  2513.745235                      2075
# 1  Rock River    Albany   200.444000                       165
# 2       Basin  Big Horn   543.951304                       250
# 3  Burlington  Big Horn   137.646214                        63
# 4       Byron  Big Horn   252.489592                       116
#
#    Population Density  Total Families
# 0                5.19         4668.93
# 1                0.41          372.30
# 2                0.66          566.43
# 3                0.17          143.34
# 4                0.31          262.93

# %%
df = df.drop(['NAME','ADDRESS','STATE','ZIP'],axis=1)
df.head()
# Out:
#        CITY  January  February  March  April    May   June   July  August  \
# 0   Buffalo    16200     13392  14688  17064  18360  14040  12960   19224
# 1    Casper    29160     21600  27000  27648  29160  27216  25488   25704
# 2  Cheyenne    79920     70632  79056  77544  73656  77976  73872   77544
# 3      Cody    19440     15984  19008  18144  16632  17496  18792   20304
# 4   Douglas    16200     13392  14688  17064  18360  14040  12960   19224
#
#    September  October  November  December
# 0      15984    13392     13176     16848
# 1      22896    25272     28944     27648
# 2      78516    74520     74736     79920
# 3      19224    18144     18576     16632
# 4      15984    29808     17496     18792

# %%
df2 = df2.drop('CASS_LastLine',axis=1)
df2.head()
# Out:
#                   BUSINESS NAME PHYSICAL CITY NAME  SALES VOLUME
# 0      Mile High Mobile Pet LLC           Cheyenne        300000
# 1                 Pets City Inc           Cheyenne        640000
# 2  Petco Animal Sups Stores Inc           Cheyenne             0
# 3                    Pet-A-Care           Cheyenne         81000
# 4          Muddy Paws Pet Salon            Laramie         76000

# %%
df['Sale'] = df.iloc[:,1:].sum(axis=1)
df.head()
# Out:
#        CITY  January  February  March  April    May   June   July  August  \
# 0   Buffalo    16200     13392  14688  17064  18360  14040  12960   19224
# 1    Casper    29160     21600  27000  27648  29160  27216  25488   25704
# 2  Cheyenne    79920     70632  79056  77544  73656  77976  73872   77544
# 3      Cody    19440     15984  19008  18144  16632  17496  18792   20304
# 4   Douglas    16200     13392  14688  17064  18360  14040  12960   19224
#
#    September  October  November  December    Sale
# 0      15984    13392     13176     16848  185328
# 1      22896    25272     28944     27648  317736
# 2      78516    74520     74736     79920  917892
# 3      19224    18144     18576     16632  218376
# 4      15984    29808     17496     18792  208008

# %%
df_sale = df[['CITY','Sale']]
df_sale
# Out:
#             CITY    Sale
# 0        Buffalo  185328
# 1         Casper  317736
# 2       Cheyenne  917892
# 3           Cody  218376
# 4        Douglas  208008
# 5       Evanston  283824
# 6       Gillette  543132
# 7         Powell  233928
# 8       Riverton  303264
# 9   Rock Springs  253584
# 10      Sheridan  308232

# %%
df1.duplicated().unique()
# Out:
# array([False])

# %%
df2.duplicated().unique()
# Out:
# array([False])

# %%
df3.duplicated().unique()
# Out:
# array([False])

# %%
df1.isnull().sum()
# Out:
# City|County      4
# 2014 Estimate    0
# 2010 Census      0
# 2000 Census      0
# dtype: int64

# %%
df1 = df1.dropna()
df1
# Out:
#                      City|County    2014 Estimate  \
# 0                  Afton|Lincoln   <td>1,968</td>
# 1                  Albin|Laramie     <td>185</td>
# 2                 Alpine|Lincoln     <td>845</td>
# 3                   Baggs|Carbon     <td>439</td>
# 4             Bairoil|Sweetwater     <td>107</td>
# 5               Bar Nunn|Natrona   <td>2,735</td>
# 6               Basin ?|Big Horn   <td>1,312</td>
# 7               Bear River|Uinta     <td>521</td>
# 8             Big Piney|Sublette     <td>538</td>
# 9              Buffalo ?|Johnson   <td>4,615</td>
# 10           Burlington|Big Horn     <td>332</td>
# 11                 Burns|Laramie     <td>305</td>
# 12                Byron|Big Horn     <td>609</td>
# 13              Casper ?|Natrona  <td>40,086</td>
# 14           Cheyenne ??|Laramie  <td>62,845</td>
# 15              Chugwater|Platte     <td>216</td>
# 16            Clearmont|Sheridan     <td>142</td>
# 17                   Cody ?|Park   <td>9,740</td>
# ...

# %%
df2.isnull().values.any()
# Out:
# False

# %%
df3.isnull().values.any()
# Out:
# False

# %%
df1[['City','Country']] = df1['City|County'].str.split('|', expand=True)

# %%
df1.head()
# Out:
#           City|County   2014 Estimate     2010 Census     2000 Census  \
# 0       Afton|Lincoln  <td>1,968</td>  <td>1,911</td>  <td>1,818</td>
# 1       Albin|Laramie    <td>185</td>    <td>181</td>    <td>120</td>
# 2      Alpine|Lincoln    <td>845</td>    <td>828</td>    <td>550</td>
# 3        Baggs|Carbon    <td>439</td>    <td>440</td>    <td>348</td>
# 4  Bairoil|Sweetwater    <td>107</td>    <td>106</td>     <td>97</td>
#
#       City     Country
# 0    Afton     Lincoln
# 1    Albin     Laramie
# 2   Alpine     Lincoln
# 3    Baggs      Carbon
# 4  Bairoil  Sweetwater

# %%
df1 = df1.drop('City|County', axis=1)
df1.head()
# Out:
#     2014 Estimate     2010 Census     2000 Census     City     Country
# 0  <td>1,968</td>  <td>1,911</td>  <td>1,818</td>    Afton     Lincoln
# 1    <td>185</td>    <td>181</td>    <td>120</td>    Albin     Laramie
# 2    <td>845</td>    <td>828</td>    <td>550</td>   Alpine     Lincoln
# 3    <td>439</td>    <td>440</td>    <td>348</td>    Baggs      Carbon
# 4    <td>107</td>    <td>106</td>     <td>97</td>  Bairoil  Sweetwater

# %%
first_column = df1.pop('Country')
df1.insert(0,'Country',first_column)
df1.head()
# Out:
#       Country   2014 Estimate     2010 Census     2000 Census     City
# 0     Lincoln  <td>1,968</td>  <td>1,911</td>  <td>1,818</td>    Afton
# 1     Laramie    <td>185</td>    <td>181</td>    <td>120</td>    Albin
# 2     Lincoln    <td>845</td>    <td>828</td>    <td>550</td>   Alpine
# 3      Carbon    <td>439</td>    <td>440</td>    <td>348</td>    Baggs
# 4  Sweetwater    <td>107</td>    <td>106</td>     <td>97</td>  Bairoil

# %%
first_column = df1.pop('City')
df1.insert(0,'City',first_column)
df1.head()
# Out:
#       City     Country   2014 Estimate     2010 Census     2000 Census
# 0    Afton     Lincoln  <td>1,968</td>  <td>1,911</td>  <td>1,818</td>
# 1    Albin     Laramie    <td>185</td>    <td>181</td>    <td>120</td>
# 2   Alpine     Lincoln    <td>845</td>    <td>828</td>    <td>550</td>
# 3    Baggs      Carbon    <td>439</td>    <td>440</td>    <td>348</td>
# 4  Bairoil  Sweetwater    <td>107</td>    <td>106</td>     <td>97</td>

# %%
df1 = df1.replace(['<td>','</td>','<sup id="cite_ref-4" class="reference">','<sup id="cite_ref-5" class="reference">','<a href="#cite_note-5">[5]</a></sup>'],'',regex=True)
df1.head()
# Out:
#       City     Country 2014 Estimate 2010 Census 2000 Census
# 0    Afton     Lincoln         1,968       1,911       1,818
# 1    Albin     Laramie           185         181         120
# 2   Alpine     Lincoln           845         828         550
# 3    Baggs      Carbon           439         440         348
# 4  Bairoil  Sweetwater           107         106          97

# %%
df1 = df1.replace(' ?','',regex=True)
df1.head()
# Out:
#       City     Country 2014 Estimate 2010 Census 2000 Census
# 0    Afton     Lincoln         1,968       1,911       1,818
# 1    Albin     Laramie           185         181         120
# 2   Alpine     Lincoln           845         828         550
# 3    Baggs      Carbon           439         440         348
# 4  Bairoil  Sweetwater           107         106          97

# %%
df1 = df1.replace('\?','',regex=True)
df1.head()
# Out:
#       City     Country 2014 Estimate 2010 Census 2000 Census
# 0    Afton     Lincoln         1,968       1,911       1,818
# 1    Albin     Laramie           185         181         120
# 2   Alpine     Lincoln           845         828         550
# 3    Baggs      Carbon           439         440         348
# 4  Bairoil  Sweetwater           107         106          97

# %%
df1 = df1.replace('<ahref="#cite_note-5">[5]</a></sup>','',regex=True)
df1.head()
# Out:
#       City     Country 2014 Estimate 2010 Census 2000 Census
# 0    Afton     Lincoln         1,968       1,911       1,818
# 1    Albin     Laramie           185         181         120
# 2   Alpine     Lincoln           845         828         550
# 3    Baggs      Carbon           439         440         348
# 4  Bairoil  Sweetwater           107         106          97

# %%
df1 = df1.replace('<a href="#cite_note-4">','',regex=True)
df1.head()
# Out:
#       City     Country 2014 Estimate 2010 Census 2000 Census
# 0    Afton     Lincoln         1,968       1,911       1,818
# 1    Albin     Laramie           185         181         120
# 2   Alpine     Lincoln           845         828         550
# 3    Baggs      Carbon           439         440         348
# 4  Bairoil  Sweetwater           107         106          97

# %%
df1 = df1.replace('</a></sup>','',regex=True)
df1.head()
# Out:
#       City     Country 2014 Estimate 2010 Census 2000 Census
# 0    Afton     Lincoln         1,968       1,911       1,818
# 1    Albin     Laramie           185         181         120
# 2   Alpine     Lincoln           845         828         550
# 3    Baggs      Carbon           439         440         348
# 4  Bairoil  Sweetwater           107         106          97

# %%
#display all rows
pd.set_option('display.max_rows',100)

# %%
df1
# Out:
#                City     Country 2014 Estimate                     2010 Census  \
# 0             Afton     Lincoln         1,968                           1,911
# 1             Albin     Laramie           185                             181
# 2            Alpine     Lincoln           845                             828
# 3             Baggs      Carbon           439                             440
# 4           Bairoil  Sweetwater           107                             106
# 5           BarNunn     Natrona         2,735                           2,213
# 6             Basin     BigHorn         1,312  1,285<ahref="#cite_note-4">[4]
# 7         BearRiver       Uinta           521                             518
# 8          BigPiney    Sublette           538                             552
# 9           Buffalo     Johnson         4,615                           4,585
# 10       Burlington     BigHorn           332                             288
# ...

# %%
df1 = df1.replace('<ahref="#cite_note-4">[4]','',regex=True)
df1
# Out:
#                City     Country 2014 Estimate                     2010 Census  \
# 0             Afton     Lincoln         1,968                           1,911
# 1             Albin     Laramie           185                             181
# 2            Alpine     Lincoln           845                             828
# 3             Baggs      Carbon           439                             440
# 4           Bairoil  Sweetwater           107                             106
# 5           BarNunn     Natrona         2,735                           2,213
# 6             Basin     BigHorn         1,312  1,285<ahref="#cite_note-4">[4]
# 7         BearRiver       Uinta           521                             518
# 8          BigPiney    Sublette           538                             552
# 9           Buffalo     Johnson         4,615                           4,585
# 10       Burlington     BigHorn           332                             288
# ...

# %%
df1.iloc[89,3]='366'
df1.iloc[89,3]
# Out:
# '366'

# %%
df1.iloc[6,3]='1285'
df1.iloc[6,3]
# Out:
# '1285'

# %%
df1
# Out:
#                City     Country 2014 Estimate 2010 Census 2000 Census
# 0             Afton     Lincoln         1,968       1,911       1,818
# 1             Albin     Laramie           185         181         120
# 2            Alpine     Lincoln           845         828         550
# 3             Baggs      Carbon           439         440         348
# 4           Bairoil  Sweetwater           107         106          97
# 5           BarNunn     Natrona         2,735       2,213         936
# 6             Basin     BigHorn         1,312        1285       1,238
# 7         BearRiver       Uinta           521         518           -
# 8          BigPiney    Sublette           538         552         408
# 9           Buffalo     Johnson         4,615       4,585       3,900
# 10       Burlington     BigHorn           332         288         250
# 11            Burns     Laramie           305         301         285
# ...

# %%
df1 = df1.drop(['Country','2014 Estimate','2000 Census'],axis=1)
df1
# Out:
#                City 2010 Census
# 0             Afton       1,911
# 1             Albin         181
# 2            Alpine         828
# 3             Baggs         440
# 4           Bairoil         106
# 5           BarNunn       2,213
# 6             Basin        1285
# 7         BearRiver         518
# 8          BigPiney         552
# 9           Buffalo       4,585
# 10       Burlington         288
# 11            Burns         301
# 12            Byron         593
# 13           Casper      35,316
# 14         Cheyenne      59,466
# 15        Chugwater         212
# 16        Clearmont         142
# 17             Cody       9,520
# 18        Cokeville         535
# 19           Cowley         655
# 20           Dayton         757
# 21           Deaver         178
# 22     Diamondville         737
# 23            Dixon          97
# 24          Douglas       6,120
# 25           Dubois         971
# 26  EastThermopolis         254
# 27         Edgerton         195
# ...

# %%
sale_join = pd.merge(df_sale,df3,how='left',left_on='CITY',right_on='City')
sale_join
# Out:
#             CITY    Sale          City      County    Land Area  \
# 0        Buffalo  185328       Buffalo     Johnson  3115.507500
# 1         Casper  317736        Casper     Natrona  3894.309100
# 2       Cheyenne  917892      Cheyenne     Laramie  1500.178400
# 3           Cody  218376          Cody        Park  2998.956960
# 4        Douglas  208008       Douglas    Converse  1829.465100
# 5       Evanston  283824      Evanston       Uinta   999.497100
# 6       Gillette  543132      Gillette    Campbell  2748.852900
# 7         Powell  233928        Powell        Park  2673.574550
# 8       Riverton  303264      Riverton     Fremont  4796.859815
# 9   Rock Springs  253584  Rock Springs  Sweetwater  6620.201916
# 10      Sheridan  308232      Sheridan    Sheridan  1893.977048
#
#     Households with Under 18  Population Density  Total Families
# 0                        746                1.55         1819.50
# 1                       7788               11.16         8756.32
# ...

# %%
sale_join2 = pd.merge(sale_join,df1,how='left',left_on='CITY',right_on='City')
sale_join2 = sale_join2.drop(['City_x','City_y'],axis=1)
sale_join2
# Out:
#             CITY    Sale      County    Land Area  Households with Under 18  \
# 0        Buffalo  185328     Johnson  3115.507500                       746
# 1         Casper  317736     Natrona  3894.309100                      7788
# 2       Cheyenne  917892     Laramie  1500.178400                      7158
# 3           Cody  218376        Park  2998.956960                      1403
# 4        Douglas  208008    Converse  1829.465100                       832
# 5       Evanston  283824       Uinta   999.497100                      1486
# 6       Gillette  543132    Campbell  2748.852900                      4052
# 7         Powell  233928        Park  2673.574550                      1251
# 8       Riverton  303264     Fremont  4796.859815                      2680
# 9   Rock Springs  253584  Sweetwater  6620.201916                      4022
# 10      Sheridan  308232    Sheridan  1893.977048                      2646
#
#     Population Density  Total Families 2010 Census
# ...

# %%
sale_join2.iloc[9,7] = '23,036'

# %%
sale_join2.iloc[9,7]
# Out:
# '23,036'

# %%
sale_join2
# Out:
#             CITY    Sale      County    Land Area  Households with Under 18  \
# 0        Buffalo  185328     Johnson  3115.507500                       746
# 1         Casper  317736     Natrona  3894.309100                      7788
# 2       Cheyenne  917892     Laramie  1500.178400                      7158
# 3           Cody  218376        Park  2998.956960                      1403
# 4        Douglas  208008    Converse  1829.465100                       832
# 5       Evanston  283824       Uinta   999.497100                      1486
# 6       Gillette  543132    Campbell  2748.852900                      4052
# 7         Powell  233928        Park  2673.574550                      1251
# 8       Riverton  303264     Fremont  4796.859815                      2680
# 9   Rock Springs  253584  Sweetwater  6620.201916                      4022
# 10      Sheridan  308232    Sheridan  1893.977048                      2646
#
#     Population Density  Total Families 2010 Census
# ...

# %%
df1.iloc[6,3]='1285'
df1.iloc[6,3]

# %%
#Change data types into numeric
sale_join2.dtypes
# Out:
# CITY                         object
# Sale                          int64
# County                       object
# Land Area                   float64
# Households with Under 18      int64
# Population Density          float64
# Total Families              float64
# 2010 Census                  object
# dtype: object

# %%
sale_join3= sale_join2.replace(',','',regex=True)
sale_join3
# Out:
#             CITY    Sale      County    Land Area  Households with Under 18  \
# 0        Buffalo  185328     Johnson  3115.507500                       746
# 1         Casper  317736     Natrona  3894.309100                      7788
# 2       Cheyenne  917892     Laramie  1500.178400                      7158
# 3           Cody  218376        Park  2998.956960                      1403
# 4        Douglas  208008    Converse  1829.465100                       832
# 5       Evanston  283824       Uinta   999.497100                      1486
# 6       Gillette  543132    Campbell  2748.852900                      4052
# 7         Powell  233928        Park  2673.574550                      1251
# 8       Riverton  303264     Fremont  4796.859815                      2680
# 9   Rock Springs  253584  Sweetwater  6620.201916                      4022
# 10      Sheridan  308232    Sheridan  1893.977048                      2646
#
#     Population Density  Total Families 2010 Census
# ...

# %%
sale_join3 = sale_join3.astype({'2010 Census':'int64'})
sale_join3.dtypes
# Out:
# CITY                         object
# Sale                          int64
# County                       object
# Land Area                   float64
# Households with Under 18      int64
# Population Density          float64
# Total Families              float64
# 2010 Census                   int64
# dtype: object

# %%
print(sale_join[['Sale', 'Land Area','Households with Under 18', 'Population Density', 'Total Families', '2010 Census']].sum())
# Out:
# Sale                        3.773304e+06
# Land Area                   3.307138e+04
# Households with Under 18    3.406400e+04
# Population Density          6.280000e+01
# Total Families              6.265279e+04
# 2010 Census                 2.138620e+05
# dtype: float64

# %%
sale_join3.describe()
# Out:
#                 Sale    Land Area  Households with Under 18  \
# count      11.000000    11.000000                 11.000000
# mean   343027.636364  3006.489126               3096.727273
# std    213538.712215  1617.460342               2453.003061
# min    185328.000000   999.497100                746.000000
# 25%    226152.000000  1861.721074               1327.000000
# 50%    283824.000000  2748.852900               2646.000000
# 75%    312984.000000  3504.908300               4037.000000
# max    917892.000000  6620.201916               7788.000000
#
#        Population Density  Total Families   2010 Census
# count           11.000000       11.000000     11.000000
# mean             5.709091     5695.708182  19442.000000
# std              5.849685     3816.049660  16616.018584
# min              1.460000     1744.080000   4585.000000
# 25%              1.720000     2923.410000   7917.000000
# 50%              2.780000     5556.490000  12359.000000
# ...

# %%
mean = sale_join3.describe().iloc[1,:]
mean
# Out:
# Sale                        343027.636364
# Land Area                     3006.489126
# Households with Under 18      3096.727273
# Population Density               5.709091
# Total Families                5695.708182
# 2010 Census                  19442.000000
# Name: mean, dtype: float64

# %%
first_Q = sale_join3.describe().iloc[4,:]
third_Q = sale_join3.describe().iloc[6,:]
print(first_Q)
print('-----------------------------------------')
print(third_Q)
# Out:
# Sale                        226152.000000
# Land Area                     1861.721074
# Households with Under 18      1327.000000
# Population Density               1.720000
# Total Families                2923.410000
# 2010 Census                   7917.000000
# Name: 25%, dtype: float64
# -----------------------------------------
# Sale                        312984.0000
# Land Area                     3504.9083
# Households with Under 18      4037.0000
# Population Density               7.3900
# Total Families                7380.8050
# 2010 Census                  26061.5000
# Name: 75%, dtype: float64

# %%
IQR = third_Q - first_Q
IQR
# Out:
# Sale                        86832.000000
# Land Area                    1643.187226
# Households with Under 18     2710.000000
# Population Density              5.670000
# Total Families               4457.395000
# 2010 Census                 18144.500000
# dtype: float64

# %%
upper = mean + 1.5*IQR
lower = mean - 1.5*IQR
print(upper)
# Out:
# Sale                        473275.636364
# Land Area                     5471.269965
# Households with Under 18      7161.727273
# Population Density              14.214091
# Total Families               12381.800682
# 2010 Census                  46658.750000
# dtype: float64

# %%
print(lower)
# Out:
# Sale                        212779.636364
# Land Area                      541.708287
# Households with Under 18      -968.272727
# Population Density              -2.795909
# Total Families                -990.384318
# 2010 Census                  -7774.750000
# dtype: float64
